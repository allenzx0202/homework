# %%
from skimage import io#,util
#import matplotlib.pyplot as plt

img1=io.imread('pic.jpg', as_grey = True)
#img2=util.img_as_ubyte(img1)

print(type(img1))
print(img1.shape)
io.imshow(img1)

#plt.figure()
#io.imshow(img2)
io.show()
# Out:
# <class 'numpy.ndarray'>
# (1920, 1440)
# C:\Users\WeiLuen\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
